# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
#
#
#
#
# ##  Pandas - Top 20 Commands which will get 80 % of your work done !

# %% [markdown]
# ##  First thing First --- Import the libraries :)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Check Pandas Version -
#
# #### Compatibility and portability issues can creep if we are using different versions on different env

# %%
pd.__version__
# Out:
# '2.0.0rc0'

# %% [markdown]
# ## Let's create a   DataFrame
#
# ## Pandas are all about DataFrame and Series ( 1 Column )
#
# ## You can create by  1) Reading a  file / DB etc... 2) Passing a Dict 3) Passing a list 4) Passing a 2D numpy array

# %%
titanic = pd.read_csv('https://raw.githubusercontent.com/anaspmachinelearning/MasterClass/main/datasets/housing/titanic.csv')

# %%
url = 'https://raw.githubusercontent.com/anaspmachinelearning/MasterClass/main/datasets/housing/titanic.csv'
separator = ','

titanic = pd.read_csv(url,sep = separator)

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
#Top 5 rows

titanic.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Pass a Dict 


df = pd.DataFrame({'Name':['Suresh', 'Rohini'], 'Gender':['Male', 'Female'] , 'Age' : [25, 23]})
df
# Out:
#      Name  Gender  Age
# 0  Suresh    Male   25
# 1  Rohini  Female   23

# %%
# define a dict and then pass 

mydict = {'Name':['Suresh', 'Rohini'], 'Gender':['Male', 'Female'] , 'Age' : [25, 23]}
df1 = pd.DataFrame(mydict)
df1
# Out:
#      Name  Gender  Age
# 0  Suresh    Male   25
# 1  Rohini  Female   23

# %%
# Sometime you would need to creata a DF with randmon variables.
# 2D numpy array 

pd.DataFrame(np.random.rand(4, 8))
# Out:
#           0         1         2         3         4         5         6
# 0  0.766855  0.750757  0.870446  0.703910  0.503585  0.458310  0.098925  \
# 1  0.119820  0.254055  0.212147  0.730112  0.283513  0.143563  0.317984
# 2  0.954432  0.685664  0.816106  0.792683  0.512495  0.877777  0.995522
# 3  0.669941  0.253848  0.411710  0.390129  0.760106  0.458939  0.519162
#
#           7
# 0  0.494115
# 1  0.883811
# 2  0.367233
# 3  0.457736

# %%
pd.DataFrame(np.random.rand(4, 8), columns=['Col 1' , 'Col 2' , 'Col 3', 'Col 4', 'Col 5','Col 6' ,'Col 7' , 
                                            'Col 8'])
# Out:
#       Col 1     Col 2     Col 3     Col 4     Col 5     Col 6     Col 7
# 0  0.514684  0.711912  0.831443  0.077684  0.634495  0.431495  0.393323  \
# 1  0.153477  0.828404  0.054311  0.428334  0.322951  0.495209  0.538640
# 2  0.811620  0.937210  0.885052  0.107241  0.250012  0.474548  0.128492
# 3  0.748534  0.844214  0.831350  0.089715  0.164407  0.561942  0.058754
#
#       Col 8
# 0  0.596882
# 1  0.432886
# 2  0.433027
# 3  0.685951

# %%
pd.DataFrame(np.random.rand(4, 8), index=['row 1' , 'row 2' , 'row 3', 'row 4'])
# Out:
#               0         1         2         3         4         5         6
# row 1  0.166918  0.104139  0.076571  0.045063  0.167002  0.477579  0.995990  \
# row 2  0.316584  0.547440  0.836588  0.967848  0.313054  0.832665  0.574403
# row 3  0.033188  0.885915  0.454512  0.413471  0.253749  0.216869  0.455844
# row 4  0.486424  0.320775  0.105226  0.014058  0.744592  0.532473  0.780341
#
#               7
# row 1  0.803390
# row 2  0.982583
# row 3  0.452375
# row 4  0.274445

# %%
pd.DataFrame(np.random.rand(4, 8), columns=['Col 1' , 'Col 2' , 'Col 3', 'Col 4', 'Col 5','Col 6' ,'Col 7' , 
                                            'Col 8'] , index=['row 1' , 'row 2' , 'row 3', 'row 4'])
# Out:
#           Col 1     Col 2     Col 3     Col 4     Col 5     Col 6     Col 7
# row 1  0.010893  0.797522  0.591734  0.212863  0.688102  0.651697  0.928091  \
# row 2  0.452214  0.857759  0.865633  0.246325  0.783331  0.476706  0.425070
# row 3  0.098987  0.704011  0.709567  0.844179  0.772455  0.641181  0.004872
# row 4  0.730911  0.413708  0.336590  0.162886  0.227500  0.432762  0.600333
#
#           Col 8
# row 1  0.887314
# row 2  0.909441
# row 3  0.534596
# row 4  0.500596

# %% [markdown]
# ## Lets rename columns

# %%
df
# Out:
#      Name  Gender  Age
# 0  Suresh    Male   25
# 1  Rohini  Female   23

# %%
df = df.rename({'Name':'First Name'}, axis='columns')

# %%
df
# Out:
#   First Name  Gender  Age
# 0     Suresh    Male   25
# 1     Rohini  Female   23

# %% [markdown]
# ##  Analyze

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name
# 886          887         0       2                     Montvila, Rev. Juozas  \
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Numerical attribute Descriptive analysis

titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp
# count   891.000000  891.000000  891.000000  714.000000  891.000000  \
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Unique count column wise 

titanic.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# ## Slicing with Loc and iLoc
#
# ### Tabular data - Pandas way of replicating List and ndarray type indexing

# %% [markdown]
# #### loc: select by labels
# #### iloc: select by positions

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.loc[:,'Name':'Parch']
# Out:
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch
# 0        0
# 1        0
# 2        0
# ...

# %%
titanic.loc[2:30,'Name':'Parch']
# Out:
#                                                  Name     Sex   Age  SibSp
# 2                              Heikkinen, Miss. Laina  female  26.0      0  \
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# ...

# %%
#iloc - index based 

titanic.iloc[1:10,1:4]
# Out:
#    Survived  Pclass                                               Name
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)

# %%
# reverse the rows

titanic.loc[::-1].head()
# Out:
#      PassengerId  Survived  Pclass                                      Name
# 890          891         0       3                       Dooley, Mr. Patrick  \
# 889          890         1       1                     Behr, Mr. Karl Howell
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 887          888         1       1              Graham, Miss. Margaret Edith
# 886          887         0       2                     Montvila, Rev. Juozas
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 890    male  32.0      0      0      370376   7.75   NaN        Q
# 889    male  26.0      0      0      111369  30.00  C148        C
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 886    male  27.0      0      0      211536  13.00   NaN        S

# %%
# reverse the columns 

titanic.loc[:,::-1].head()
# Out:
#   Embarked Cabin     Fare            Ticket  Parch  SibSp   Age     Sex
# 0        S   NaN   7.2500         A/5 21171      0      1  22.0    male  \
# 1        C   C85  71.2833          PC 17599      0      1  38.0  female
# 2        S   NaN   7.9250  STON/O2. 3101282      0      0  26.0  female
# 3        S  C123  53.1000            113803      0      1  35.0  female
# 4        S   NaN   8.0500            373450      0      0  35.0    male
#
#                                                 Name  Pclass  Survived
# 0                            Braund, Mr. Owen Harris       3         0  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1         1
# 2                             Heikkinen, Miss. Laina       3         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1         1
# 4                           Allen, Mr. William Henry       3         0
#
#    PassengerId
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5

# %% [markdown]
# ## Conditional Filtering Techniques

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Check the unique value counts !

titanic.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
titanic[(titanic.Embarked == 'S') & (titanic.Sex == 'female') & (titanic.Survived == 1 )].head()
# Out:
#     PassengerId  Survived  Pclass
# 2             3         1       3  \
# 3             4         1       1
# 8             9         1       3
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp
# 2                              Heikkinen, Miss. Laina  female  26.0      0  \
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 8       2            347742  11.1333   NaN        S
# 10      1           PP 9549  16.7000    G6        S
# ...

# %%
# Filter it in this way as well ! 

titanic[( titanic["Embarked"] == 'S') & (titanic["Sex"] == 'female') & (titanic["Survived"] == 1) ].head()
# Out:
#     PassengerId  Survived  Pclass
# 2             3         1       3  \
# 3             4         1       1
# 8             9         1       3
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp
# 2                              Heikkinen, Miss. Laina  female  26.0      0  \
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 8       2            347742  11.1333   NaN        S
# 10      1           PP 9549  16.7000    G6        S
# ...

# %%
# Find the count by a categorical attribute

titanic.Survived.value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# ## missing values

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# A quicker way to get the null value count for each column

titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# various ways to deal with missing values 

# Drop the column entirely or set a threshold

titanic.dropna(axis='columns').head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  SibSp  Parch
# 0                            Braund, Mr. Owen Harris    male      1      0  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                             Heikkinen, Miss. Laina  female      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                           Allen, Mr. William Henry    male      0      0
#
#              Ticket     Fare
# 0         A/5 21171   7.2500
# 1          PC 17599  71.2833
# 2  STON/O2. 3101282   7.9250
# 3            113803  53.1000
# 4            373450   8.0500

# %%
# Age column survived!

titanic.dropna(thresh=len(titanic)*0.8, axis='columns').head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
### Row drop - NaN values


titanic.dropna( axis='index').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 183 entries, 1 to 889
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  183 non-null    int64
#  1   Survived     183 non-null    int64
#  2   Pclass       183 non-null    int64
#  3   Name         183 non-null    object
#  4   Sex          183 non-null    object
#  5   Age          183 non-null    float64
#  6   SibSp        183 non-null    int64
#  7   Parch        183 non-null    int64
#  8   Ticket       183 non-null    object
#  9   Fare         183 non-null    float64
#  10  Cabin        183 non-null    object
#  11  Embarked     183 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 18.6+ KB

# %%
# Fill with some values 

titanic["Cabin"].fillna("Default Cabin" , inplace = True)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Get the value count for how many were replaced.
titanic.Cabin.value_counts()
# Out:
# Cabin
# Default Cabin    687
# C23 C25 C27        4
# G6                 4
# B96 B98            4
# C22 C26            3
#                 ...
# E34                1
# C7                 1
# C54                1
# E36                1
# C148               1
# Name: count, Length: 148, dtype: int64

# %% [markdown]
# ## Sorting

# %%
titanic.sort_values(by = 'Fare' , ascending = False )
# Out:
#      PassengerId  Survived  Pclass                                Name
# 258          259         1       1                    Ward, Miss. Anna  \
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
# ..           ...       ...     ...                                 ...
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 732          733         0       2                Knight, Mr. Robert J
# 674          675         0       2          Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch    Ticket      Fare          Cabin Embarked
# ...

# %%
# Index->Rows  and Values -> Columns

titanic.sort_index(ascending = False)
# Out:
#      PassengerId  Survived  Pclass
# 890          891         0       3  \
# 889          890         1       1
# 888          889         0       3
# 887          888         1       1
# 886          887         0       2
# ..           ...       ...     ...
# 4              5         0       3
# 3              4         1       1
# 2              3         1       3
# 1              2         1       1
# 0              1         0       3
#
#                                                   Name     Sex   Age  SibSp
# 890                                Dooley, Mr. Patrick    male  32.0      0  \
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Aggregation

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare          Cabin Embarked
# 0      0         A/5 21171   7.2500  Default Cabin        S
# 1      0          PC 17599  71.2833            C85        C
# 2      0  STON/O2. 3101282   7.9250  Default Cabin        S
# 3      0            113803  53.1000           C123        S
# ...

# %%
# Those who survived what was their mean Fare

titanic[titanic.Survived == 1].Fare.mean()
# Out:
# 48.39540760233918

# %%
# Those who didn't survive what was their mean Fare

titanic[titanic.Survived == 0].Fare.mean()
# Out:
# 22.117886885245902

# %%
titanic.groupby('Survived').Fare.agg(['sum', 'count','mean']).head()
# Out:
#                  sum  count       mean
# Survived
# 0         12142.7199    549  22.117887
# 1         16551.2294    342  48.395408

# %% [markdown]
# ## continuous data into categorical data
#
# ## Think of a situation when it will be needed ( Hint : Histogram )

# %%
titanic.Age.head(10)
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64

# %%
titanic["Updated Age"] = pd.cut(titanic.Age, bins=[0, 18, 25, 99], labels=['child', 'young adult', 
                                                                           'adult']).head(10)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare          Cabin Embarked  Updated Age
# 0      0         A/5 21171   7.2500  Default Cabin        S  young adult
# 1      0          PC 17599  71.2833            C85        C        adult
# 2      0  STON/O2. 3101282   7.9250  Default Cabin        S        adult
# ...

# %%
titanic.drop("Age" , axis = 1)
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch
# 0                              Braund, Mr. Owen Harris    male      1      0  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %% [markdown]
# ## Convert data types of columns to reduce size

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     889 non-null    object
#  12  Updated Age  9 non-null      category
# dtypes: category(1), float64(2), int64(5), object(5)
# memory usage: 84.7+ KB

# %%
titanic.head(20)
# Out:
#     PassengerId  Survived  Pclass
# 0             1         0       3  \
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp
# 0                             Braund, Mr. Owen Harris    male  22.0      1  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare          Cabin Embarked  Updated Age
# 0      0         A/5 21171   7.2500  Default Cabin        S  young adult
# 1      0          PC 17599  71.2833            C85        C        adult
# 2      0  STON/O2. 3101282   7.9250  Default Cabin        S        adult
# ...

# %%
titanic["Sex"] = titanic["Sex"].astype("category")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    category
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     889 non-null    object
#  12  Updated Age  9 non-null      category
# dtypes: category(2), float64(2), int64(5), object(4)
# memory usage: 78.7+ KB

# %% [markdown]
# ##  Super Hero version of Pandas - ydata_profiling

# %%
# !pip install ydata_profiling
# Out:
# ...
#   Using cached pandas-1.5.3-cp39-cp39-macosx_10_9_x86_64.whl (12.0 MB)
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.0rc0
#     Uninstalling pandas-2.0.0rc0:
#       Successfully uninstalled pandas-2.0.0rc0
# ...

# %%
import ydata_profiling
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/c7/xpmf_mm11rzd7287lvvlg39r0000gq/T/ipykernel_45293/1121382538.py in <module>
# ----> 1 import ydata_profiling
#
# ~/opt/anaconda3/lib/python3.9/site-packages/ydata_profiling/__init__.py in <module>
#       5 import importlib.util
#       6
# ----> 7 from ydata_profiling.compare_reports import compare
#       8 from ydata_profiling.controller import pandas_decorator
#       9 from ydata_profiling.profile_report import ProfileReport
#
# ~/opt/anaconda3/lib/python3.9/site-packages/ydata_profiling/compare_reports.py in <module>
#       5
#       6 from ydata_profiling.config import Correlation, Settings
# ----> 7 from ydata_profiling.model.alerts import Alert
#       8 from ydata_profiling.profile_report import ProfileReport
#       9
#
# ...

# %%
ydata_profiling.ProfileReport(titanic)
