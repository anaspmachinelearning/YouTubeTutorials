# %% [markdown]
# #    15 Matplotlib Commands which will get 80% of your work done !

# %% [markdown]
# # 1. Importing Matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# #  2.  Magic Command for Jupyter

# %%
#magic command to show in Jupyter Notebook

# %matplotlib inline

# %% [markdown]
# #  3. First plot using plt.plot

# %%
import numpy as np

x = np.array([1, 2, 6, 8])
y = np.array([3, 8, 1, 10])
y1 = np.array([5, 7, 10, 5])

fig = plt.figure()

plt.plot(x, y, '-')
plt.plot(x, y1, '-');

# %% [markdown]
# #   4. Saving to file

# %%
fig.savefig('my_figure.png')

# %% [markdown]
# We now have a file called ``my_figure.png`` in the current working directory:

# %%
# !ls -lh my_figure.png
# Out:
# -rw-r--r--  1 anasp  staff    35K Mar 10 08:08 my_figure.png

# %%
# To display from Disk 

from IPython.display import Image
Image('my_figure.png')

# %% [markdown]
# # 5. Playing with Options

# %%
# For short, you can use the following codes:
plt.plot(x, y, linestyle='dashed', color='black', marker='o',markersize=12, linewidth=2)  # solid

# %% [markdown]
# #  6. Adjusting the Plot: Axes Limits

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5);

# %%
x
# Out:
# array([1, 2, 6, 8])

# %%
y
# Out:
# array([ 3,  8,  1, 10])

# %% [markdown]
# # 7. Labeling Plots

# %%
plt.plot(x, y)
plt.title("A Simple graph")
plt.plot(x, y, '-g', label='first graph')
plt.plot(x, y1, ':b', label='second graph')

plt.legend();

# %% [markdown]
# # 8. Scatter Plots

# %%
plt.scatter(x, y, marker='o');

# %% [markdown]
# # 9. Histogram and Bins

# %%
data = np.random.randn(1000)

# %%
plt.hist(data);

# %%
plt.hist(data, bins=10,
         histtype='stepfilled', color='steelblue',
         edgecolor='black');

# %% [markdown]
# # 10. Bar plot

# %%
plt.bar(x, y, color='green')
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # 11. Pie Chart

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "pink", "yellow", "red"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# # 12. Combine plots

# %%
plt.plot(x, y, color= 'blue', lw=4, alpha=0.5)
plt.scatter(x, y, marker='o', s=400, color='red',alpha=0.5)
plt.bar(x, y, color= 'green',alpha=0.5)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
#  # 13. Sub Plots

# %%
#plot 1:

plt.subplot(2, 2, 1)
plt.plot(x,y)

#plot 2:

plt.subplot(2, 2, 2)
plt.plot(x **2 ,y **2)


#plot 3:

plt.subplot(2, 2, 3)
plt.plot(x * 2,y * 2)


plt.show()

# %% [markdown]
# # 14.  Quick Styles

# %%
plt.style.available[:]
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('dark_background')
plt.hist(data);

# %%
plt.style.use('seaborn')
plt.hist(data);

# %%
plt.style.available[:]
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# # 15. 3-d Plotting

# %%
from mpl_toolkits import mplot3d

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

Z = f(X, Y)

# %%
# Why we are not using plt.plot here ? why plt.axes ? What's the difference ? 

ax = plt.axes(projection='3d')

ax.plot_surface(X, Y, Z);

# %% [markdown]
# #### Drawing 3d in 2d- Contours

# %%
plt.contour(X, Y, Z, colors='black');
